# %%
import matplotlib.pyplot as plt
import numpy as np
import os, json
import pandas as pd
import seaborn as sns
import json

# %%
def json_to_df(path_to_json):
    # Source - https://stackoverflow.com/a
    # Posted by Scott, modified by community. See post 'Timeline' for change history
    # Retrieved 2026-01-26, License - CC BY-SA 3.0
    
    json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
    df_list = []
    for f in json_files:
        with open(path_to_json+f) as json_data:
            data = json.load(json_data)
            json_data.close()
    
        hyperparams = ['D', 'N', 'K', 'n_clients', 'lambda', 'lr', 'seed', 'runtime_sec']
        ll = ['ll_c', 'll_l', 'fl_ll']
        results = {k: v for k, v in data.items() if k not in hyperparams}

        rows = []
        # for key, value in results.items():
        #     parts = key.split('_vs_')
        #     algorithm = parts[0]
        #     metric = parts[1]
        
        #     # handle augmentation
        #     if metric.endswith('_aug'):
        #         algorithm += '_aug'
        #         metric = metric.replace('_aug', '')
        
        #     rows.append({
        #         **{k: data[k] for k in hyperparams},
        #         'algorithm': algorithm,
        #         'metric': f'err_{metric}',
        #         'value': value
        #     })
        rows.append({
            **{k: data[k] for k in hyperparams},
            'algorithm': 'central',
            'Log-likelihood': results['ll_c'],
            'err_true': results['centralized_vs_true'],
            'err_central': None
        })
        rows.append({
            **{k: data[k] for k in hyperparams},
            'algorithm': 'local',
            'Log-likelihood': results['ll_l'],
            'err_true': results['local_vs_true'],
            'err_central': results['local_vs_central']
        })
        rows.append({
            **{k: data[k] for k in hyperparams},
            'algorithm': 'fl',
            'Log-likelihood': results['fl_ll'],
            'err_true': results['fl_vs_true'],
            'err_central': results['fl_vs_central']
        })
        rows.append({
            **{k: data[k] for k in hyperparams},
            'algorithm': 'fl_aug',
            'Log-likelihood': results['fl_aug_ll'],
            'err_true': results['fl_vs_true_aug'],
            'err_central': results['fl_vs_central_aug']
        })
        df_list.append(pd.DataFrame(rows))
    return pd.concat(df_list, ignore_index=True)

# %%
df = json_to_df('results_iid/')

# %%
df.head()
# Out:
#    D    N  K  n_clients  lambda      lr  seed  runtime_sec algorithm  \
# 0  4  100  3         10     1.0  0.0005     2  3493.393287   central
# 1  4  100  3         10     1.0  0.0005     2  3493.393287     local
# 2  4  100  3         10     1.0  0.0005     2  3493.393287        fl
# 3  4  100  3         10     1.0  0.0005     2  3493.393287    fl_aug
# 4  8   50  3         10     1.0  0.0005     3  3205.807429   central
#
#    Log-likelihood  err_true  err_central
# 0       -6.787103  0.099240          NaN
# 1       -6.902941  0.344921     0.329345
# 2       -6.831146  0.239419     0.219627
# 3       -6.828022  0.238138     0.212900
# 4      -12.472397  0.213003          NaN

# %%
for d in [2,4,8,16]:
    for m in [10,25,50,100]:
        print(d,m)
        print(len(df[ (df["N"]==m) & (df["D"]==d) & (df["lambda"]==0)]))
# Out:
# 2 10
# 40
# 2 25
# 40
# 2 50
# 40
# 2 100
# 40
# 4 10
# 40
# 4 25
# 40
# 4 50
# 40
# 4 100
# 40
# 8 10
# 40
# 8 25
# 40
# 8 50
# 40
# 8 100
# 40
# 16 10
# 0
# 16 25
# 0
# 16 50
# 0
# 16 100
# 0

# %%
# 398        -5.210869  1.156296     1.095477
# 399        -5.305790  1.006492     0.972931
# 680        -3.973247  0.229072          NaN
# 681        -7.006244  0.706336     0.670824
# 682        -7.012364  0.706622     0.671188
# 683        -7.021294  0.707668     0.672219
# 784        -3.903519  0.256482          NaN
# 785        -8.952865  0.986762     0.974620
# 786        -8.936311  0.909930     0.891177
# 787        -8.571732  0.908192     0.866832
# 988        -3.992744  0.171664          NaN
# 989        -6.718245  0.682446     0.642902
# 990        -6.725430  0.685465     0.645446
# 991        -6.727128  0.681919     0.642744
# 1112       -4.028057  0.266084          NaN
# 1113       -7.509111  0.700698     0.634253
# 1114       -7.537434  0.700941     0.634005
# 1115       -7.503281  0.702454     0.635878
# 1220       -3.859921  0.200445          NaN
# 1221       -7.310889  1.027491     1.039575
# 1222       -6.729116  0.750468     0.739451
# 1223       -6.534274  0.859054     0.828916
# 1272       -3.617111  2.512298          NaN
# 1273      -12.210558  1.431289     1.956915
# 1274      -12.537437  1.327644     2.145462
# 1275      -12.204400  1.551951     2.084585
# 1376       -4.018653  0.201870          NaN
# 1377       -7.693902  0.610251     0.589025
# 1378       -7.690257  0.607684     0.586944
# 1379       -7.705253  0.610343     0.589930

# %%
df_lambda_05 = df[ (df["lambda"]==0.5)]

# %%
plot_metric_line(
    df = df_lambda_05,
    x_label = "D",
    metric = "err_true",
    col = "N",
    algorithms=["local", "central", "fl", "fl_aug"],
    # custom_palette=custom_palette,
    label_map=None,
    # y_label_map=y_label_map,
    x_label_map=None,
    y_limits=None,
    sharey=True,
    height=4,
    aspect=1,
    save=False,
    fig_name=None
)

# %%
plot_metric_line(
    df = df_lambda_05,
    x_label = "D",
    metric = "err_true",
    col = "N",
    algorithms=["local", "central", "fl", "fl_aug"],
    # custom_palette=custom_palette,
    label_map=None,
    # y_label_map=y_label_map,
    x_label_map=None,
    y_limits=None,
    sharey=True,
    height=4,
    aspect=1,
    save=False,
    fig_name=None
)

# %%
def plot_metric_line(
    df,
    x_label,
    metric,
    col,
    algorithms=None,
    # custom_palette=custom_palette,
    label_map=None,
    # y_label_map=y_label_map,
    x_label_map=None,
    y_limits=None,
    sharey=True,
    height=4,
    aspect=1,
    save=False,
    fig_name=None
):
    assert metric in df.columns, f"Metric '{metric}' not found in DataFrame."

    df_plot = df.copy()
    if algorithms is not None:
        df_plot = df_plot[df_plot["algorithm"].isin(algorithms)]

    # Create FacetGrid
    g = sns.FacetGrid(
        df_plot,
        col=col,
        height=height,
        aspect=aspect,
        sharey=sharey
    )

    # Plot with lineplot
    g.map_dataframe(
        sns.lineplot,
        x=x_label,
        y=metric,
        hue="algorithm",
        style="algorithm",
        marker="o",
        markersize=8,
        # err_style="bars",
        errorbar=("se", 1),
        err_kws={"linewidth": 2.5},
        linewidth=2,
        # palette=custom_palette
    )

    # Set x-axis ticks to be consistent
    x_ticks = sorted(df_plot[x_label].unique())
    for ax in g.axes.flat:
        ax.set_xticks(x_ticks)
        ax.tick_params(axis='both', which='major', labelsize=20) 
        ax.grid(True, axis="y", linestyle="--", alpha=0.7)
        ax.grid(False, axis="x")

    # Set subplot titles and axis labels
    g.set_titles(f"{col} = {{col_name}}", size=24)
    g.set_axis_labels(x_label, r"$\it{" + metric + "}$", fontsize=20)

    # Use mapped label 
    # y_label = y_label_map.get(metric, r"$\it{" + metric + "}$") if y_label_map else r"$\it{" + metric + "}$"
    # g.set_axis_labels(x_label, y_label, fontsize=24)

    # Set y-limits per subplot if specified
    if y_limits:
        for ax, d_val in zip(g.axes.flat, df_plot[col].unique()):
            if d_val in y_limits:
                ax.set_ylim(*y_limits[d_val])

    # Set x-label only on bottom row
    for ax in g.axes.flat:
        ax.set_xlabel("")
    mid_index = len(g.axes.flat) // 2
    # if x_label_map : x_label = x_label_map[x_label]
    # g.axes.flat[mid_index].set_xlabel(r"$\it{" + x_label + "}$")
    if x_label == "p_out":
        x_label_latex = r"$p_{\mathrm{out}}$"
    elif x_label == "alpha":
         x_label_latex = r"$\alpha$"
    else:
        x_label_latex = r"$\it{" + x_label + "}$"

    g.axes.flat[mid_index].set_xlabel(x_label_latex, fontsize=24)

    # Handle legend
    handles, labels = g.axes.flat[-1].get_legend_handles_labels()
    if label_map:
        labels = [label_map.get(label, label) for label in labels]

    g.fig.legend(
        handles,
        labels,
        loc="lower center",
        ncol=len(set(labels)),
        frameon=False,
        fontsize=21,
        bbox_to_anchor=(0.5, -0.2),
        columnspacing=0.8
    )

    # Adjust layout to fit legend
    g.fig.subplots_adjust(bottom=0.22)

    if save and fig_name:
        plt.savefig(fig_name, bbox_inches="tight", dpi=300)

    plt.show()

# %%
plot_metric_line(
    df = df_lambda_05,
    x_label = "D",
    metric = "Log-likelihood",
    col = "N",
    algorithms=["local", "central", "fl", "fl_aug"],
    # custom_palette=custom_palette,
    label_map=None,
    # y_label_map=y_label_map,
    x_label_map=None,
    y_limits=None,
    sharey=True,
    height=4,
    aspect=1,
    save=False,
    fig_name=None
)

# %%
plot_metric_line(
    df = df_lambda_05,
    x_label = "D",
    metric = "err_central",
    col = "N",
    algorithms=["local", "central", "fl", "fl_aug"],
    # custom_palette=custom_palette,
    label_map=None,
    # y_label_map=y_label_map,
    x_label_map=None,
    y_limits=None,
    sharey=True,
    height=4,
    aspect=1,
    save=False,
    fig_name=None
)

# %%
plot_metric_line(
    df = df_lambda_05,
    x_label = "D",
    metric = "err_true",
    col = "N",
    algorithms=["local", "central", "fl", "fl_aug"],
    # custom_palette=custom_palette,
    label_map=None,
    # y_label_map=y_label_map,
    x_label_map=None,
    y_limits=None,
    sharey=True,
    height=4,
    aspect=1,
    save=False,
    fig_name=None
)

# %%
plot_metric_line(
    df = df_lambda_05,
    x_label = "D",
    metric = "value",
    col = "N",
    algorithms=["local", "fl", "fl_aug"],
    # custom_palette=custom_palette,
    label_map=None,
    # y_label_map=y_label_map,
    x_label_map=None,
    y_limits=None,
    sharey=True,
    height=4,
    aspect=1,
    save=False,
    fig_name=None
)

# %%
rows = []

for key, value in results.items():
    parts = key.split('_vs_')
    algorithm = parts[0]
    metric = parts[1]

    # handle augmentation
    if metric.endswith('_aug'):
        algorithm += '_aug'
        metric = metric.replace('_aug', '')

    rows.append({
        **{k: data[k] for k in hyperparams},
        'algorithm': algorithm,
        'metric': f'err_{metric}',
        'value': value
    })

df_tidy = pd.DataFrame(rows)
df_tidy
# Out:
#     D   N  K  n_clients  lambda      lr  seed  runtime_sec    algorithm  \
# 0  16  50  3         10     0.0  0.0005     6   648.633177  centralized
# 1  16  50  3         10     0.0  0.0005     6   648.633177        local
# 2  16  50  3         10     0.0  0.0005     6   648.633177        local
# 3  16  50  3         10     0.0  0.0005     6   648.633177           fl
# 4  16  50  3         10     0.0  0.0005     6   648.633177           fl
# 5  16  50  3         10     0.0  0.0005     6   648.633177       fl_aug
# 6  16  50  3         10     0.0  0.0005     6   648.633177       fl_aug
#
#         metric     value
# 0     err_true  0.333768
# 1     err_true  0.950970
# 2  err_central  0.893243
# 3     err_true  0.952023
# 4  err_central  0.894223
# 5     err_true  0.950732
# 6  err_central  0.893288

# %%
# Source - https://stackoverflow.com/a
# Posted by Juan Estevez, modified by community. See post 'Timeline' for change history
# Retrieved 2026-01-26, License - CC BY-SA 4.0

dfs = [] # an empty list to store the data frames
for file in json_files:
    data = pd.read_json('results/'+file, lines=True) # read data frame from json file
    dfs.append(data) # append the data frame to the list

df = pd.concat(dfs, ignore_index=True) # concatenate all the data frames in the list.
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 7
#       5 dfs = [] # an empty list to store the data frames
#       6 for file in json_files:
# ----> 7     data = pd.read_json('results/'+file, lines=True) # read data frame from json file
#       8     dfs.append(data) # append the data frame to the list
#      10 df = pd.concat(dfs, ignore_index=True) # concatenate all the data frames in the list.
#
# File ~/miniconda3/envs/hetFL/lib/python3.12/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~/miniconda3/envs/hetFL/lib/python3.12/site-packages/pandas/io/json/_json.py:1023, in JsonReader.read(self)
#    1021         data = ensure_str(self.data)
#    1022         data_lines = data.split("\n")
# -> 1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
#    1025     obj = self._get_object_parser(self.data)
#
# File ~/miniconda3/envs/hetFL/lib/python3.12/site-packages/pandas/io/json/_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File ~/miniconda3/envs/hetFL/lib/python3.12/site-packages/pandas/io/json/_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File ~/miniconda3/envs/hetFL/lib/python3.12/site-packages/pandas/io/json/_json.py:1403, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
#    1402     self.obj = DataFrame(
# -> 1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# ValueError: Expected object or value

# %%
proportions = [10, 20, 30]
n_k = 57
diff = n_k - np.sum(proportions) 
diff
# Out:
# -3

# %%
np.sign(diff)
# Out:
# -1

# %%
for i in range(abs(diff)):
    proportions[i % 3] += np.sign(diff)
proportions
# Out:
# [9, 19, 29]

# %%
sum(proportions)
# Out:
# 57
